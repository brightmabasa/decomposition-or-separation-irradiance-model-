# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_RMSE_ALL.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('RMSE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_RMSE_ALLSKY.png", dpi=300)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_MAE_ALL.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('MAE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_MAE_ALLSKY.png", dpi=300)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_MAE_CS.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('MAE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_MAE_CS.png", dpi=300)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_RMSE_CS.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('RMSE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_RMSE_CS.png", dpi=300)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_MAE_OV.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('MAE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_MAE_OV.png", dpi=300)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("KD_RMSE_OV.csv")

# Extract and sort RMSE values
model_rmse = df.iloc[0]
sorted_rmse = model_rmse.sort_values()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sorted_rmse.index, sorted_rmse.values, color='grey', width=0.5)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.ylabel('RMSE', fontsize=14)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Save the figure
plt.savefig("KD_RMSE_OV.png", dpi=300)

# Display the plot
plt.show()
